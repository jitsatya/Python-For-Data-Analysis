# %%
import numpy as np
import pandas as pd

data = pd.read_csv("Datasets/matches - matches.csv")

# %%
#Bar chart
import matplotlib.pyplot as plt # Importing so that the plot gets visualized and not just created

data['winner'].value_counts().head(8).plot(kind='bar') # creating bar chart
# Out:
# <AxesSubplot:>

# %%
data['winner'].value_counts().head(8).plot(kind='barh') # horizontal bar chart
# Out:
# <AxesSubplot:>

# %%
data['toss_decision'].value_counts().plot(kind = 'pie') # pie chart
# Out:
# <AxesSubplot:ylabel='toss_decision'>

# %%
data['win_by_runs'].plot(kind='hist') # histogram
# Out:
# <AxesSubplot:ylabel='Frequency'>
